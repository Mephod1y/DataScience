# %% [markdown]
# <a href="https://colab.research.google.com/github/Mephod1y/DataScience/blob/main/Hw2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('https://drive.google.com/uc?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U')

# %%
# Прочитайте отриману таблицю, використовуючи метод head
data.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
# Визначте розмір таблиці за допомогою методу shape
data.shape
# Out:
# (8704, 25)

# %%
# Визначте типи всіх стовпців за допомогою dataframe.dtypes
data.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
data.isnull().sum()/len(data)*100
# Out:
# N                                    0.000000
# Должность                            0.000000
# Язык.программирования               44.232537
# Специализация                       82.938879
# Общий.опыт.работы                    0.000000
# Опыт.работы.на.текущем.месте         0.000000
# Зарплата.в.месяц                     0.000000
# Изменение.зарплаты.за.12.месяцев     0.000000
# Город                                0.000000
# Размер.компании                      0.000000
# Тип.компании                         0.000000
# Пол                                  0.000000
# Возраст                              0.000000
# Образование                          0.000000
# Университет                          4.113051
# Еще.студент                          0.000000
# Уровень.английского                  0.000000
# Предметная.область                   2.562040
# Дата.заполнения                      0.000000
# User.Agent                           0.000000
# ...

# %%
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
data1 = ['Язык.программирования'] + list(data.dropna(axis=1, how='any').columns)
data = data[data1]
data.head()
# Out:
#   Язык.программирования  N                 Должность Общий.опыт.работы  \
# 0                   NaN  1        Junior QA engineer               0.5
# 1                   NaN  2        Junior QA engineer  меньше 3 месяцев
# 2               C#/.NET  3         Software Engineer                 4
# 3            JavaScript  4         Software Engineer                 5
# 4            JavaScript  5  Senior Software Engineer    10 и более лет
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                          0.5               400
# 1             меньше 3 месяцев               430
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                 0  Харьков       до 10 человек
# 1                               130  Харьков  свыше 1000 человек
# ...

# %%
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"
data.isnull().sum()/len(data)*100
# Out:
# Язык.программирования               44.232537
# N                                    0.000000
# Должность                            0.000000
# Общий.опыт.работы                    0.000000
# Опыт.работы.на.текущем.месте         0.000000
# Зарплата.в.месяц                     0.000000
# Изменение.зарплаты.за.12.месяцев     0.000000
# Город                                0.000000
# Размер.компании                      0.000000
# Тип.компании                         0.000000
# Пол                                  0.000000
# Возраст                              0.000000
# Образование                          0.000000
# Еще.студент                          0.000000
# Уровень.английского                  0.000000
# Дата.заполнения                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# dtype: float64

# %%
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna
data = data.dropna()

# %%
# Визначте новий розмір таблиці за допомогою методу shape
data.shape
# Out:
# (4854, 20)

# %%
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data = data[data['Язык.программирования']=="Python"]
python_data
# Out:
#      Язык.программирования     N                 Должность Общий.опыт.работы  \
# 12                  Python    13         Software Engineer                 1
# 68                  Python    69         Software Engineer               1.5
# 87                  Python    88  Junior Software Engineer               0.5
# 114                 Python   115  Junior Software Engineer               1.5
# 143                 Python   144  Junior Software Engineer                 1
# ...                    ...   ...                       ...               ...
# 8546                Python  8547         Software Engineer                 5
# 8625                Python  8626         Software Engineer                 4
# 8635                Python  8636  Senior Software Engineer    10 и более лет
# 8673                Python  8674  Junior Software Engineer               0.5
# 8695                Python  8696         Software Engineer                 1
#
# ...

# %%
# Визначте розмір таблиці python_data за допомогою методу shape
python_data.shape
# Out:
# (207, 20)

# %%
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"
python_job = python_data.groupby(['Должность'])
job, data1 = next(iter(python_job))
job
data1.head()
# Out:
# <ipython-input-139-ce5952275cc6>:3: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   job, data1 = next(iter(python_job))
#     Язык.программирования    N                 Должность Общий.опыт.работы  \
# 87                 Python   88  Junior Software Engineer               0.5
# 114                Python  115  Junior Software Engineer               1.5
# 143                Python  144  Junior Software Engineer                 1
# 162                Python  163  Junior Software Engineer               0.5
# 171                Python  172  Junior Software Engineer              0.25
#
#     Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 87                           0.5               600
# 114                          0.5               685
# 143                            1               750
# ...

# %%
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"
grouped_data = python_data.groupby(['Должность']).agg({'Зарплата.в.месяц': ['mean', 'min', 'max']})
grouped_data
# Out:
#                          Зарплата.в.месяц
#                                      mean   min   max
# Должность
# Junior Software Engineer       560.841270   100  1250
# Senior Software Engineer      3387.096774  1300  9200
# Software Engineer             1799.070000   500  5400
# System Architect              4000.000000  3000  5000
# Technical Lead                3165.909091  1425  6200

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"
df1 = python_data.groupby(['Должность'])
agg_func = {'Зарплата.в.месяц':['min', 'max']}
df2 = df1.agg(agg_func)
def fill_avg_salary(row):
    return row.mean()
df2['avg'] = df2.apply(fill_avg_salary, axis=1)
df2
# Out:
#                          Зарплата.в.месяц           avg
#                                       min   max
# Должность
# Junior Software Engineer              100  1250   675.0
# Senior Software Engineer             1300  9200  5250.0
# Software Engineer                     500  5400  2950.0
# System Architect                     3000  5000  4000.0
# Technical Lead                       1425  6200  3812.5

# %%
# Створіть описову статистику за допомогою методу describe для нового стовпчика.
df3 = df2['avg'].describe(include='all')
df3
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %%
# Збережіть отриману таблицю в CSV файл
df3.to_csv("data.csv", index=False)

# %%
import matplotlib.pyplot as plt

jobs = python_data.groupby(['Должность']).agg({'Должность': ['count']})
jobs['Должность','count']

labels = [
    "Junior Software Engineer",
    "Senior Software Engineer",
    "Software Engineer",
    "System Architect",
    "Technical Lead",
]
dataset = jobs['Должность','count']
plt.pie(
    dataset,
    labels=labels,
    shadow=True,
    autopct="%.2f%%",
)
plt.show()

# %%
lang = data.groupby(['Язык.программирования'], as_index=False).count().sort_values('N')
plt.bar(lang['Язык.программирования'],lang['N'])
plt.title("Кількість фахівців по мова програмування", fontsize=15)
plt.xticks(rotation=30, ha='right')
plt.show()
